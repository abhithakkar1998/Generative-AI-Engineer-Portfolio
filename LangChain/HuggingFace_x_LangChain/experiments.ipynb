# %%
# !pip install langchain_huggingface --quiet
# Out:
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import os
from dotenv import load_dotenv
load_dotenv('/home/abhi/AI_Workspace/personal/Generative-AI-Engineer-Portfolio/.env')

os.environ["HUGGINGFACEHUB_API_TOKEN"] = os.getenv("HF_TOKEN")

# %%
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "You are a helpful AI Assistant."),
        ("human", "Answer this:\n{question}")
    ]
)

# %%
repo_id = "deepseek-ai/DeepSeek-V3.1"

llm = HuggingFaceEndpoint(
    repo_id=repo_id,
    max_new_tokens=512,
    do_sample=False,
    provider="auto",
)

chat_model = ChatHuggingFace(llm=llm)

# %%
llm_chain = prompt | chat_model

# %%
response = llm_chain.invoke(
    {
        "question": "What is the capital of France?"
    }
)
print(response.content)
# Out:
# The capital of France is **Paris**.

# %%
chat_model.invoke("what is the capital of France?")
# Out:
# AIMessage(content='The capital of France is **Paris**.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 11, 'total_tokens': 20}, 'model_name': 'deepseek-ai/DeepSeek-V3.1', 'system_fingerprint': '', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c56f3-6771-74f3-b691-87f0f97e3664-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 11, 'output_tokens': 9, 'total_tokens': 20})

# %%
chat_model.invoke("what is Aritificial Intelligence?")
# Out:
# AIMessage(content='Of course! Here is a detailed yet easy-to-understand explanation of what Artificial Intelligence (AI) is.\n\n### A Simple Definition\n\nAt its core, **Artificial Intelligence (AI) is the field of computer science dedicated to creating machines and software that can perform tasks that typically require human intelligence.**\n\nThis includes things like:\n*   Learning from experience (**\n*   Understanding language (**\n*   Recognizing patterns and objects (**\n*   Solving problems\n*   Making decisions\n\n---\n\n### A Helpful Analogy: The Human Brain\n\nThink of AI as an attempt to build a simplified, digital version of the human brain.\n\n*   **The Brain (Hardware):** This is the computer\'s hardware (CPUs, GPUs) that provides the raw computational power, similar to our biological brain.\n*   **The Algorithm (The Mind):** This is the set of rules or instructions the computer follows. It\'s the "thinking" process.\n*   **The Data (The Experiences):** This is the inf
# ...

# %%
repo_id_2 = "zai-org/GLM-5"

llm_2 = HuggingFaceEndpoint(
    repo_id=repo_id_2,
    max_new_tokens=512,
    do_sample=False,
    provider="auto",
)

chat_model_2 = ChatHuggingFace(llm=llm_2)

# %%
chat_model_2.invoke("What is the model you're based on?")
# Out:
# AIMessage(content="I'm GLM, a large language model developed by Z.ai. My architecture is based on the General Language Model (GLM) framework, which uses an autoregressive training approach to understand and generate human language.\n\nI was trained on a diverse corpus of textual data, which helps me understand and respond to a wide range of topics and questions. My training involves learning patterns in language to provide informative and relevant responses.\n\nIs there something specific about my capabilities or how I can assist you that you'd like to know more about?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 384, 'prompt_tokens': 14, 'total_tokens': 398}, 'model_name': 'zai-org/GLM-5', 'system_fingerprint': '', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c56f8-a7db-7ca2-a66a-72d5d6c66d09-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 14, 'output_tokens': 384, 'total_tokens': 398})
