# %%
import nltk

# %%
corpus = """
Hello Everyone. Welcome to this NLP's tutorial.
Please do read the entire notebook! to understand the basic usage
of nltk library.
"""
print(corpus)
# Out:
# Hello Everyone. Welcome to this NLP's tutorial.
# Please do read the entire notebook! to understand the basic usage
# of nltk library.

# %%
#Tokenization
from nltk.tokenize import sent_tokenize

# %%
documents = sent_tokenize(corpus)
print(documents)
# Out:
# ['\nHello Everyone.', "Welcome to this NLP's tutorial.", 'Please do read the entire notebook!', 'to understand the basic usage\nof nltk library.']

# %%
from nltk.tokenize import word_tokenize
word_tokenize(corpus)
# Out:
# ['Hello',
#  'Everyone',
#  '.',
#  'Welcome',
#  'to',
#  'this',
#  'NLP',
#  "'s",
#  'tutorial',
#  '.',
#  'Please',
#  'do',
#  'read',
#  'the',
#  'entire',
#  'notebook',
#  '!',
#  'to',
#  'understand',
#  'the',
#  'basic',
#  'usage',
#  'of',
#  'nltk',
#  'library',
#  '.']

# %%
for sent in documents:
    print(word_tokenize(sent))
# Out:
# ['Hello', 'Everyone', '.']
# ['Welcome', 'to', 'this', 'NLP', "'s", 'tutorial', '.']
# ['Please', 'do', 'read', 'the', 'entire', 'notebook', '!']
# ['to', 'understand', 'the', 'basic', 'usage', 'of', 'nltk', 'library', '.']

# %%
from nltk.tokenize import wordpunct_tokenize
for sent in documents:
    print(wordpunct_tokenize(sent))
# Out:
# ['Hello', 'Everyone', '.']
# ['Welcome', 'to', 'this', 'NLP', "'", 's', 'tutorial', '.']
# ['Please', 'do', 'read', 'the', 'entire', 'notebook', '!']
# ['to', 'understand', 'the', 'basic', 'usage', 'of', 'nltk', 'library', '.']

# %%
from nltk.tokenize import TreebankWordTokenizer
tokenizer = TreebankWordTokenizer()
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'Everyone.',
#  'Welcome',
#  'to',
#  'this',
#  'NLP',
#  "'s",
#  'tutorial.',
#  'Please',
#  'do',
#  'read',
#  'the',
#  'entire',
#  'notebook',
#  '!',
#  'to',
#  'understand',
#  'the',
#  'basic',
#  'usage',
#  'of',
#  'nltk',
#  'library',
#  '.']
